# %%
import pandas as pd

# List of file paths - adjust paths to match where the files are stored
file_paths = [
    'allergy_data_500.csv',
    'cancer_data_100.csv',
    'general_disease_data_1000.csv',
    "general_disease_data_1000_diverse.csv"
]

# Read all CSV files into DataFrames
dataframes = [pd.read_csv(file) for file in file_paths]

# Concatenate all DataFrames
combined_df = pd.concat(dataframes, ignore_index=True)

# Save the combined DataFrame to a new CSV file
combined_file_path = 'combined_data.csv'
combined_df.to_csv(combined_file_path, index=False)

print(f"Combined data saved to {combined_file_path}")
# Out:
# Combined data saved to combined_data.csv

# %%
import pandas as pd
import random

# Generate realistic and varied data for 10 patients
data = {
    "PatientID": [f"P00{i+1}" for i in range(10)],
    "Age": [random.randint(25, 80) for _ in range(10)],
    "Gender": random.choices(["Male", "Female"], k=10),
    "Ethnicity": random.choices(["Caucasian", "Asian", "African American", "Hispanic"], k=10),
    "Doctor": [f"Dr. {random.choice(['Smith', 'Johnson', 'Lee', 'Brown', 'Davis'])}" for _ in range(10)],
    "Medication": random.choices(
        ["Atorvastatin", "Albuterol", "Metformin", "Lisinopril", "Insulin", "Ibuprofen", "Omeprazole", "Amoxicillin"],
        k=10),
    "TreatmentPlan": random.choices(
        ["Oxygen therapy", "Increase dietary iron", "Inhaler use", "Steroids and oxygen", "Diet and exercise", "Daily insulin", 
         "Antibiotics for infection", "Pain management"], k=10),
    "DoctorSpecialty": random.choices(
        ["Pulmonologist", "Endocrinologist", "Cardiologist", "General Practitioner", "Hematologist", "Rheumatologist"], k=10),
    "DiagnosisDate": pd.date_range(start="2023-01-01", periods=10).strftime("%Y-%m-%d").tolist(),
    "Clinical Note": [
        "A 70-year-old male with a history of COPD presents with worsening shortness of breath over the past few days. Oxygen therapy was initiated.",
        "A 45-year-old female reports chronic fatigue and was diagnosed with iron-deficiency anemia. Iron supplements were prescribed.",
        "A 60-year-old male was seen for high blood pressure. Lisinopril was prescribed to manage the condition.",
        "A 30-year-old female reports severe asthma attacks. She was advised to use an Albuterol inhaler as needed.",
        "A 65-year-old male with type 2 diabetes presented with high blood sugar levels. Insulin therapy was initiated.",
        "A 55-year-old female diagnosed with rheumatoid arthritis was started on a regimen of NSAIDs for pain management.",
        "A 28-year-old male with recurrent sinus infections was prescribed Amoxicillin.",
        "A 50-year-old female reports severe GERD symptoms. Omeprazole was prescribed to manage acid reflux.",
        "A 75-year-old male with a history of cardiovascular disease was prescribed Atorvastatin to manage cholesterol.",
        "A 40-year-old female was diagnosed with type 2 diabetes and advised to follow a strict diet and exercise regimen."
    ],
    "ICD10Code": ["J44.9", "D50.9", "I10", "J45.909", "E11.9", "M06.9", "J01.90", "K21.9", "E78.5", "E11.9"],
    "PrimaryDiagnosis": [
        "COPD", "Anemia", "Hypertension", "Asthma", "Diabetes", "Rheumatoid Arthritis", "Sinusitis", "GERD", "Hyperlipidemia", "Diabetes"],
    "Allergies": ["None", "Peanuts", "Shellfish", "None", "Penicillin", "None", "Latex", "None", "None", "None"],
    "BloodType": random.choices(["O+", "A+", "B+", "AB+", "O-", "A-", "B-", "AB-"], k=10),
    "SmokingStatus": random.choices(["Former Smoker", "Never Smoked", "Current Smoker"], k=10),
    "AlcoholUse": random.choices(["Occasional", "Never", "Regular"], k=10),
    "BMI": [round(random.uniform(18.5, 35), 1) for _ in range(10)],
    "ChronicConditions": [
        "COPD", "Anemia", "Hypertension", "Asthma", "Diabetes", "Rheumatoid Arthritis", "Sinusitis", "GERD", "Cardiovascular Disease", "Diabetes"],
    "FamilyHistory": [
        "Heart Disease", "Diabetes", "Hypertension", "Asthma", "Thyroid Disease", "Arthritis", "Allergies", "GERD", "Stroke", "Diabetes"],
    "MedicationsHistory": ["Metformin", "Iron supplements", "Lisinopril", "Albuterol", "Insulin", "Ibuprofen", "Amoxicillin", "Omeprazole", "Atorvastatin", "Metformin"],
    "Hospitalizations": random.choices([0, 1, 2, 3], k=10),
    "Surgeries": random.choices(
        ["Appendectomy", "None", "Knee Replacement", "None", "Gallbladder Removal", "None", "None", "Hernia Repair", "None", "None"], k=10),
    "Immunizations": ["Flu Shot", "Flu Shot", "Pneumonia Vaccine", "Flu Shot", "Tetanus", "Flu Shot", "Flu Shot", "Shingles Vaccine", "Flu Shot", "Flu Shot"],
    "LabResults": [
        "Elevated cholesterol", "Low iron", "High blood pressure", "Normal", "High blood sugar", "Elevated CRP", "Infection present", "Acidic pH level", "Normal", "Elevated blood sugar"],
    "PrimaryCareProvider": [f"Dr. {random.choice(['Johnson', 'Williams', 'Martinez', 'Brown', 'Taylor'])}" for _ in range(10)]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
output_file = 'realistic_clinical_notes.csv'
df.to_csv(output_file, index=False)

output_file
# Out:
# 'realistic_clinical_notes.csv'

# %%
# Append the new data directly to the existing CSV file

# Load the existing CSV file
existing_df = pd.read_csv('realistic_clinical_notes.csv')

# Create the new DataFrame (this is the new data to append)
data_new = {
    "PatientID": [f"P01{i+1}" for i in range(10)],
    "Age": [55, 38, 62, 45, 70, 30, 25, 65, 50, 45],
    "Gender": ["Male", "Female", "Male", "Female", "Male", "Male", "Female", "Male", "Male", "Female"],
    "Ethnicity": ["Caucasian", "Asian", "African American", "Hispanic", "Caucasian", "Caucasian", "Asian", "African American", "Hispanic", "Caucasian"],
    "Doctor": [f"Dr. {random.choice(['Anderson', 'Thomas', 'White', 'Miller', 'Garcia'])}" for _ in range(10)],
    "Medication": random.choices(
        ["Nebulizer", "Antispasmodic", "Antiplatelet", "Sumatriptan", "Lisinopril", "Pain medication", "Antihistamine", "Radiation therapy", "DMARDs", "SSRI"],
        k=10),
    "TreatmentPlan": random.choices(
        ["Nebulizer use", "Low FODMAP diet", "Angioplasty and antiplatelet therapy", "Migraine diary", "Low-sodium diet", 
         "Physical therapy", "Avoid allergens", "Radiation therapy", "Rheumatologist referral", "Cognitive-behavioral therapy"],
        k=10),
    "DoctorSpecialty": random.choices(
        ["Pulmonologist", "Gastroenterologist", "Cardiologist", "Neurologist", "General Practitioner", "Orthopedist", "Allergist", "Oncologist", "Rheumatologist", "Psychiatrist"],
        k=10),
    "DiagnosisDate": pd.date_range(start="2024-02-01", periods=10).strftime("%Y-%m-%d").tolist(),
    "Clinical Note": [
        "A 55-year-old male patient presents with a persistent cough and shortness of breath. The patient has a known history of COPD. After a physical examination, the patient was advised to start using a nebulizer along with his current medication regimen to help open the airways and make breathing easier.",
        "A 38-year-old female patient reports severe abdominal pain and bloating. After ruling out common gastrointestinal issues, she was diagnosed with irritable bowel syndrome (IBS) and was advised to follow a low FODMAP diet along with prescribed antispasmodic medication to manage the symptoms.",
        "The patient, a 62-year-old male, was admitted with chest pain radiating to his left arm. ECG results confirmed the presence of an acute myocardial infarction. The patient was immediately taken to the cath lab for an angioplasty procedure and was started on antiplatelet therapy post-surgery.",
        "A 45-year-old female patient has been experiencing frequent migraines that last several hours. The migraines are accompanied by nausea and sensitivity to light. She was prescribed sumatriptan and advised to maintain a migraine diary to identify potential triggers.",
        "A 70-year-old male was seen for routine follow-up after a recent stroke. The patient has shown significant improvement in mobility and speech. He is continuing with physical and occupational therapy and was advised to start a low-sodium diet to manage his hypertension, a contributing factor to the stroke.",
        "The patient, aged 30, presents with severe lower back pain that has been persistent for the last two weeks. After an MRI, the patient was diagnosed with a herniated disc. A referral to a physical therapist was made, and the patient was prescribed pain medication to manage discomfort during the therapy.",
        "A 25-year-old female with a history of seasonal allergies reports increased symptoms this year, including itchy eyes and a runny nose. She was prescribed a daily antihistamine and was advised to avoid outdoor activities during peak pollen times to minimize exposure to allergens.",
        "The patient, a 65-year-old male, was diagnosed with prostate cancer following an elevated PSA test and biopsy results. The patient discussed treatment options with his oncologist and decided to proceed with radiation therapy. He was also referred to a urologist for further management of urinary symptoms.",
        "A 50-year-old male patient presents with persistent joint pain and stiffness, especially in the morning. Lab results revealed elevated rheumatoid factor, and the patient was diagnosed with rheumatoid arthritis. He was started on DMARDs (disease-modifying antirheumatic drugs) and referred to a rheumatologist for ongoing care.",
        "A 45-year-old female patient reports experiencing significant anxiety and insomnia for the past few months. After an assessment, she was diagnosed with generalized anxiety disorder and prescribed a low dose of an SSRI. Cognitive-behavioral therapy (CBT) was also recommended as part of her treatment plan."
    ],
    "ICD10Code": ["J44.9", "K58.0", "I21.9", "G43.909", "I63.9", "M51.2", "J30.9", "C61", "M06.9", "F41.1"],
    "PrimaryDiagnosis": [
        "COPD", "IBS", "Myocardial Infarction", "Migraines", "Stroke", "Herniated Disc", "Seasonal Allergies", "Prostate Cancer", "Rheumatoid Arthritis", "Generalized Anxiety Disorder"],
    "Allergies": ["None", "None", "Shellfish", "None", "None", "None", "Peanuts", "None", "None", "None"],
    "BloodType": random.choices(["O+", "A+", "B+", "AB+", "O-", "A-", "B-", "AB-"], k=10),
    "SmokingStatus": random.choices(["Former Smoker", "Never Smoked", "Current Smoker"], k=10),
    "AlcoholUse": random.choices(["Occasional", "Never", "Regular"], k=10),
    "BMI": [round(random.uniform(18.5, 35), 1) for _ in range(10)],
    "ChronicConditions": [
        "COPD", "IBS", "Heart Disease", "Migraines", "Hypertension", "Herniated Disc", "Seasonal Allergies", "Cancer", "Rheumatoid Arthritis", "Anxiety"],
    "FamilyHistory": [
        "Heart Disease", "Diabetes", "Hypertension", "Migraines", "Stroke", "Arthritis", "Allergies", "Cancer", "Arthritis", "Mental Health Disorders"],
    "MedicationsHistory": ["None"] * 10,
    "Hospitalizations": random.choices([0, 1, 2, 3], k=10),
    "Surgeries": random.choices(
        ["Appendectomy", "None", "Coronary Bypass", "None", "None", "None", "None", "Prostate Surgery", "None", "None"], k=10),
    "Immunizations": ["Flu Shot"] * 10,
    "LabResults": [
        "Elevated CRP", "Normal", "High Troponin", "Normal", "Elevated Blood Pressure", "Herniated Disc Confirmed", "Normal", "Elevated PSA", "Elevated Rheumatoid Factor", "Normal"],
    "PrimaryCareProvider": [f"Dr. {random.choice(['Baker', 'Wilson', 'Martinez', 'Clark', 'Taylor'])}" for _ in range(10)]
}

# Create the new DataFrame
df_new = pd.DataFrame(data_new)

# Append the new data to the existing DataFrame
combined_df = pd.concat([existing_df, df_new], ignore_index=True)

# Save the combined DataFrame back to the original CSV file
combined_file_path = 'realistic_clinical_notes.csv'
combined_df.to_csv(combined_file_path, index=False)

combined_file_path
# Out:
# 'realistic_clinical_notes.csv'

# %%
# Append the new data directly to the existing CSV file

# Load the existing CSV file
existing_df = pd.read_csv('realistic_clinical_notes.csv')

# Create the new DataFrame (this is the new data to append)
data_new = {
    "PatientID": [f"P02{i+1}" for i in range(10)],
    "Age": [60, 47, 34, 72, 29, 51, 66, 45, 58, 33],
    "Gender": ["Female", "Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female", "Male"],
    "Ethnicity": ["African American", "Caucasian", "Hispanic", "Asian", "Caucasian", "African American", "Hispanic", "Asian", "Caucasian", "African American"],
    "Doctor": [f"Dr. {random.choice(['Johnson', 'Brown', 'Davis', 'Moore', 'Taylor'])}" for _ in range(10)],
    "Medication": random.choices(
        ["Metformin", "Lisinopril", "Aspirin", "Omeprazole", "Albuterol", "Gabapentin", "Warfarin", "Ibuprofen", "Citalopram", "Hydrochlorothiazide"],
        k=10),
    "TreatmentPlan": random.choices(
        ["Diet modification", "Exercise regimen", "Medication adherence", "Smoking cessation", "Regular monitoring", 
         "Physical therapy", "Mental health counseling", "Nutritional supplements", "Regular follow-up", "Vaccination schedule"],
        k=10),
    "DoctorSpecialty": random.choices(
        ["Endocrinologist", "Cardiologist", "Gastroenterologist", "Pulmonologist", "Neurologist", "Psychiatrist", "Orthopedist", "Hematologist", "Dermatologist", "Rheumatologist"],
        k=10),
    "DiagnosisDate": pd.date_range(start="2024-03-01", periods=10).strftime("%Y-%m-%d").tolist(),
    "Clinical Note": [
        "The patient, a 60-year-old female, presented with high blood sugar levels despite ongoing treatment. After reviewing her current regimen, her medication was adjusted, and she was advised to follow a stricter diet plan to better manage her diabetes.",
        "A 47-year-old male came in with complaints of recurring chest pain. The pain was aggravated by physical activity and relieved by rest. An ECG was performed, and it was decided to adjust his heart medications and recommend lifestyle changes.",
        "The patient, a 34-year-old female, was evaluated for persistent acid reflux. She was prescribed a proton pump inhibitor and advised to avoid trigger foods such as spicy and fatty meals. Further testing was suggested if symptoms do not improve.",
        "A 72-year-old male with a history of chronic obstructive pulmonary disease (COPD) reported worsening breathlessness. The patient's inhaler prescription was renewed, and he was encouraged to join a pulmonary rehabilitation program to manage his symptoms.",
        "The 29-year-old female presented with symptoms of generalized anxiety, including insomnia and difficulty concentrating. Cognitive-behavioral therapy was recommended alongside a low dose of an anxiolytic medication.",
        "A 51-year-old male with neuropathic pain in his extremities was evaluated. His medication dosage was increased, and he was referred to a pain specialist for further management. Regular follow-ups were scheduled to monitor progress.",
        "The 66-year-old female patient presented with chronic joint pain, primarily in her knees. She was diagnosed with osteoarthritis and was prescribed NSAIDs for pain relief, along with physical therapy to maintain joint function.",
        "The patient, a 45-year-old male, was seen for follow-up regarding his hypertension. Despite adherence to his treatment plan, his blood pressure remained elevated. His medication was adjusted, and additional dietary recommendations were made.",
        "A 58-year-old female reported symptoms of depression, including low mood and lack of interest in daily activities. She was started on an SSRI and referred to a therapist for cognitive-behavioral therapy.",
        "The patient, a 33-year-old male, presented with recurring migraines. After evaluation, his treatment was adjusted to include a prophylactic medication, and he was advised to track his headache patterns and potential triggers."
    ],
    "ICD10Code": ["E11.9", "I20.9", "K21.9", "J44.9", "F41.1", "G62.9", "M19.90", "I10", "F32.9", "G43.909"],
    "PrimaryDiagnosis": [
        "Type 2 Diabetes Mellitus", "Angina Pectoris", "Gastroesophageal Reflux Disease", "Chronic Obstructive Pulmonary Disease", "Generalized Anxiety Disorder",
        "Peripheral Neuropathy", "Osteoarthritis", "Hypertension", "Major Depressive Disorder", "Migraine"],
    "Allergies": ["None", "Penicillin", "None", "Latex", "None", "None", "Peanuts", "None", "None", "Shellfish"],
    "BloodType": random.choices(["A+", "O+", "B+", "AB+", "O-", "A-", "B-", "AB-"], k=10),
    "SmokingStatus": random.choices(["Former Smoker", "Never Smoked", "Current Smoker"], k=10),
    "AlcoholUse": random.choices(["Occasional", "Never", "Regular"], k=10),
    "BMI": [round(random.uniform(19.0, 32.0), 1) for _ in range(10)],
    "ChronicConditions": [
        "Diabetes", "Heart Disease", "Gastroesophageal Reflux", "COPD", "Anxiety", "Neuropathy", "Arthritis", "Hypertension", "Depression", "Migraines"],
    "FamilyHistory": [
        "Diabetes", "Heart Disease", "GERD", "Respiratory Diseases", "Mental Health Disorders", "Diabetes", "Arthritis", "Hypertension", "Mental Health Disorders", "Migraines"],
    "MedicationsHistory": ["Metformin", "Aspirin", "Omeprazole", "Albuterol", "Citalopram", "Gabapentin", "Ibuprofen", "Lisinopril", "SSRIs", "Triptans"],
    "Hospitalizations": random.choices([0, 1, 2], k=10),
    "Surgeries": random.choices(
        ["None", "None", "Appendectomy", "None", "None", "None", "Knee Replacement", "None", "None", "Appendectomy"], k=10),
    "Immunizations": ["Flu Shot"] * 10,
    "LabResults": [
        "Elevated HbA1c", "Normal ECG", "Elevated Acid Levels", "Normal Spirometry", "Elevated Cortisol", "Elevated Fasting Blood Sugar", "Normal", "Elevated Blood Pressure", "Low Serotonin", "Normal"],
    "PrimaryCareProvider": [f"Dr. {random.choice(['Harris', 'Jones', 'King', 'Lewis', 'Scott'])}" for _ in range(10)]
}

# Create the new DataFrame
df_new = pd.DataFrame(data_new)

# Append the new data to the existing DataFrame
combined_df = pd.concat([existing_df, df_new], ignore_index=True)

# Save the combined DataFrame back to the original CSV file
combined_file_path = 'realistic_clinical_notes.csv'
combined_df.to_csv(combined_file_path, index=False)

combined_file_path
# Out:
# 'realistic_clinical_notes.csv'

# %%
# Append the new data directly to the existing CSV file

# Load the existing CSV file
existing_df = pd.read_csv('realistic_clinical_notes.csv')

# Create the new DataFrame (this is the new data to append)
data_new = {
    "PatientID": [f"P03{i+1}" for i in range(10)],
    "Age": [64, 49, 37, 55, 73, 32, 61, 46, 59, 40],
    "Gender": ["Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female"],
    "Ethnicity": ["Caucasian", "Hispanic", "Asian", "African American", "Caucasian", "Hispanic", "African American", "Asian", "Caucasian", "Hispanic"],
    "Doctor": [f"Dr. {random.choice(['Williams', 'Rodriguez', 'Martinez', 'Lee', 'Garcia'])}" for _ in range(10)],
    "Medication": random.choices(
        ["Metoprolol", "Levothyroxine", "Prednisone", "Amoxicillin", "Sertraline", "Losartan", "Furosemide", "Atorvastatin", "Insulin", "Hydroxychloroquine"],
        k=10),
    "TreatmentPlan": random.choices(
        ["Blood pressure monitoring", "Thyroid hormone replacement", "Steroid therapy", "Antibiotic course", "Depression management", 
         "Hypertension control", "Diuretic therapy", "Cholesterol management", "Diabetes management", "Autoimmune therapy"],
        k=10),
    "DoctorSpecialty": random.choices(
        ["Cardiologist", "Endocrinologist", "Pulmonologist", "Infectious Disease Specialist", "Psychiatrist", "Nephrologist", "Rheumatologist", "Dermatologist", "Endocrinologist", "General Practitioner"],
        k=10),
    "DiagnosisDate": pd.date_range(start="2024-04-01", periods=10).strftime("%Y-%m-%d").tolist(),
    "Clinical Note": [
        "A 64-year-old male presents with persistent hypertension despite adherence to his current medication. His treatment plan was adjusted to include a higher dose of Metoprolol, and he was advised to monitor his blood pressure at home regularly.",
        "The patient, a 49-year-old female, was diagnosed with hypothyroidism after presenting with fatigue, weight gain, and dry skin. Levothyroxine was prescribed, and she was instructed to follow up in six weeks for a re-evaluation of thyroid function.",
        "A 37-year-old male came in with severe shortness of breath and wheezing. He was diagnosed with acute asthma exacerbation and was started on a course of Prednisone along with his regular inhaler therapy.",
        "The patient, a 55-year-old female, presented with a fever and sore throat. A rapid strep test confirmed streptococcal pharyngitis. She was prescribed Amoxicillin and advised to complete the entire course of antibiotics.",
        "A 73-year-old male with a history of major depressive disorder reported worsening symptoms, including increased irritability and sleep disturbances. His Sertraline dosage was increased, and cognitive-behavioral therapy was recommended.",
        "The patient, a 32-year-old female, was seen for management of her chronic hypertension. Despite medication, her blood pressure remained elevated. Losartan was added to her regimen, and she was advised to reduce sodium intake and engage in regular physical activity.",
        "A 61-year-old male with a history of chronic kidney disease presented with fluid retention and shortness of breath. Furosemide was prescribed as a diuretic to manage his symptoms, and a follow-up appointment was scheduled.",
        "The patient, a 46-year-old female, was evaluated for high cholesterol levels. Atorvastatin was prescribed, and she was advised to follow a low-cholesterol diet and engage in regular exercise to manage her lipid profile.",
        "A 59-year-old male with type 2 diabetes was experiencing poor glycemic control despite current therapy. His Insulin regimen was adjusted, and he was educated on carbohydrate counting and regular blood glucose monitoring.",
        "The patient, a 40-year-old female, presented with joint pain and fatigue. After extensive testing, she was diagnosed with lupus. Hydroxychloroquine was prescribed, and she was referred to a rheumatologist for ongoing management of her autoimmune condition."
    ],
    "ICD10Code": ["I10", "E03.9", "J45.901", "J02.0", "F33.9", "I10", "N18.9", "E78.0", "E11.9", "M32.9"],
    "PrimaryDiagnosis": [
        "Hypertension", "Hypothyroidism", "Asthma Exacerbation", "Streptococcal Pharyngitis", "Major Depressive Disorder",
        "Hypertension", "Chronic Kidney Disease", "Hypercholesterolemia", "Type 2 Diabetes Mellitus", "Systemic Lupus Erythematosus"],
    "Allergies": ["Penicillin", "None", "None", "Sulfa Drugs", "None", "None", "Latex", "None", "None", "None"],
    "BloodType": random.choices(["O+", "A+", "B+", "AB+", "O-", "A-", "B-", "AB-"], k=10),
    "SmokingStatus": random.choices(["Never Smoked", "Former Smoker", "Current Smoker"], k=10),
    "AlcoholUse": random.choices(["Occasional", "Never", "Regular"], k=10),
    "BMI": [round(random.uniform(20.0, 33.0), 1) for _ in range(10)],
    "ChronicConditions": [
        "Hypertension", "Hypothyroidism", "Asthma", "Infections", "Depression", "Hypertension", "Kidney Disease", "High Cholesterol", "Diabetes", "Lupus"],
    "FamilyHistory": [
        "Heart Disease", "Thyroid Disease", "Asthma", "Infections", "Mental Health Disorders", "Hypertension", "Kidney Disease", "Heart Disease", "Diabetes", "Autoimmune Disorders"],
    "MedicationsHistory": ["Metoprolol", "Levothyroxine", "Prednisone", "Amoxicillin", "Sertraline", "Losartan", "Furosemide", "Atorvastatin", "Insulin", "Hydroxychloroquine"],
    "Hospitalizations": random.choices([0, 1, 2], k=10),
    "Surgeries": random.choices(
        ["None", "Thyroidectomy", "None", "Tonsillectomy", "None", "None", "Kidney Transplant", "None", "None", "None"], k=10),
    "Immunizations": ["Flu Shot"] * 10,
    "LabResults": [
        "Elevated Blood Pressure", "Low TSH", "Normal Spirometry", "Positive Strep Test", "Elevated Cortisol", "High Blood Pressure", "Elevated Creatinine", "High LDL", "Elevated HbA1c", "Positive ANA"],
    "PrimaryCareProvider": [f"Dr. {random.choice(['Miller', 'Davis', 'Garcia', 'Martinez', 'Wilson'])}" for _ in range(10)]
}

# Create the new DataFrame
df_new = pd.DataFrame(data_new)

# Append the new data to the existing DataFrame
combined_df = pd.concat([existing_df, df_new], ignore_index=True)

# Save the combined DataFrame back to the original CSV file
combined_file_path = 'realistic_clinical_notes.csv'
combined_df.to_csv(combined_file_path, index=False)

combined_file_path
# Out:
# 'realistic_clinical_notes.csv'

# %%
# Append the new data directly to the existing CSV file

# Load the existing CSV file
existing_df = pd.read_csv('realistic_clinical_notes.csv')

# Create the new DataFrame (this is the new data to append)
data_new = {
    "PatientID": [f"P04{i+1}" for i in range(10)],
    "Age": [53, 41, 68, 36, 50, 29, 74, 58, 46, 39],
    "Gender": ["Female", "Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female", "Male"],
    "Ethnicity": ["Hispanic", "Asian", "Caucasian", "African American", "Caucasian", "Asian", "African American", "Hispanic", "Caucasian", "African American"],
    "Doctor": [f"Dr. {random.choice(['Scott', 'Adams', 'Parker', 'Lopez', 'Mitchell'])}" for _ in range(10)],
    "Medication": random.choices(
        ["Propranolol", "Amlodipine", "Ciprofloxacin", "Gabapentin", "Omeprazole", "Fluticasone", "Metformin", "Simvastatin", "Citalopram", "Hydrochlorothiazide"],
        k=10),
    "TreatmentPlan": random.choices(
        ["Heart rate management", "Blood pressure control", "Antibiotic treatment", "Nerve pain management", "Acid reflux control", 
         "Asthma management", "Blood sugar control", "Cholesterol management", "Depression management", "Diuretic therapy"],
        k=10),
    "DoctorSpecialty": random.choices(
        ["Cardiologist", "Nephrologist", "Infectious Disease Specialist", "Neurologist", "Gastroenterologist", "Pulmonologist", "Endocrinologist", "Cardiologist", "Psychiatrist", "Nephrologist"],
        k=10),
    "DiagnosisDate": pd.date_range(start="2024-05-01", periods=10).strftime("%Y-%m-%d").tolist(),
    "Clinical Note": [
        "The patient, a 53-year-old female, has been experiencing episodes of tachycardia and was prescribed Propranolol for heart rate control. She was advised to monitor her symptoms and report any side effects immediately.",
        "A 41-year-old male presented with elevated blood pressure during his annual check-up. Amlodipine was prescribed to manage his hypertension, and he was counseled on lifestyle modifications including diet and exercise.",
        "The patient, a 68-year-old female, reported symptoms of a urinary tract infection, including dysuria and frequent urination. Ciprofloxacin was prescribed, and the patient was instructed to complete the entire antibiotic course.",
        "A 36-year-old male with a history of chronic back pain reported worsening symptoms. Gabapentin was added to his treatment plan for neuropathic pain, and he was referred to a pain management specialist for further evaluation.",
        "The patient, a 50-year-old female, presented with persistent acid reflux. Omeprazole was prescribed for symptom relief, and dietary modifications were recommended to prevent recurrence.",
        "A 29-year-old male with a history of asthma reported increased use of his rescue inhaler. Fluticasone was prescribed as a maintenance inhaler, and he was advised to follow up in two months to assess control.",
        "The patient, a 74-year-old female, with type 2 diabetes, had poorly controlled blood sugar levels. Her Metformin dosage was increased, and she was educated on the importance of dietary management and regular glucose monitoring.",
        "A 58-year-old male with high cholesterol levels was prescribed Simvastatin. He was advised to follow a low-fat diet and engage in regular physical activity to enhance the effectiveness of the medication.",
        "The patient, a 46-year-old female, was seen for follow-up regarding her depression. Her Citalopram dosage was adjusted, and she was encouraged to continue attending her counseling sessions for better management of her symptoms.",
        "A 39-year-old male with a history of hypertension presented with fluid retention. Hydrochlorothiazide was prescribed as a diuretic, and the patient was advised to reduce sodium intake and increase water consumption."
    ],
    "ICD10Code": ["I47.1", "I10", "N39.0", "M54.5", "K21.9", "J45.909", "E11.9", "E78.0", "F33.1", "I12.9"],
    "PrimaryDiagnosis": [
        "Paroxysmal Tachycardia", "Hypertension", "Urinary Tract Infection", "Chronic Back Pain", "Gastroesophageal Reflux Disease",
        "Asthma", "Type 2 Diabetes Mellitus", "Hypercholesterolemia", "Major Depressive Disorder", "Hypertension with Chronic Kidney Disease"],
    "Allergies": ["Penicillin", "None", "Sulfa Drugs", "None", "None", "None", "None", "None", "None", "None"],
    "BloodType": random.choices(["A+", "O+", "B+", "AB+", "O-", "A-", "B-", "AB-"], k=10),
    "SmokingStatus": random.choices(["Never Smoked", "Former Smoker", "Current Smoker"], k=10),
    "AlcoholUse": random.choices(["Occasional", "Never", "Regular"], k=10),
    "BMI": [round(random.uniform(18.0, 34.0), 1) for _ in range(10)],
    "ChronicConditions": [
        "Heart Disease", "Hypertension", "Infections", "Chronic Pain", "GERD", "Asthma", "Diabetes", "High Cholesterol", "Depression", "Kidney Disease"],
    "FamilyHistory": [
        "Heart Disease", "Hypertension", "Kidney Disease", "Arthritis", "GERD", "Asthma", "Diabetes", "High Cholesterol", "Mental Health Disorders", "Hypertension"],
    "MedicationsHistory": ["Propranolol", "Amlodipine", "Ciprofloxacin", "Gabapentin", "Omeprazole", "Fluticasone", "Metformin", "Simvastatin", "Citalopram", "Hydrochlorothiazide"],
    "Hospitalizations": random.choices([0, 1, 2], k=10),
    "Surgeries": random.choices(
        ["None", "None", "Appendectomy", "None", "None", "None", "None", "None", "None", "Appendectomy"], k=10),
    "Immunizations": ["Flu Shot"] * 10,
    "LabResults": [
        "Elevated Heart Rate", "High Blood Pressure", "Positive Urine Culture", "Normal Nerve Conduction", "Elevated Acid Levels", "Normal Spirometry", "Elevated HbA1c", "High LDL", "Low Serotonin", "Elevated Creatinine"],
    "PrimaryCareProvider": [f"Dr. {random.choice(['Smith', 'Johnson', 'Clark', 'Ramirez', 'Turner'])}" for _ in range(10)]
}

# Create the new DataFrame
df_new = pd.DataFrame(data_new)

# Append the new data to the existing DataFrame
combined_df = pd.concat([existing_df, df_new], ignore_index=True)

# Save the combined DataFrame back to the original CSV file
combined_file_path = 'realistic_clinical_notes.csv'
combined_df.to_csv(combined_file_path, index=False)

combined_file_path
# Out:
# 'realistic_clinical_notes.csv'

# %%
# Append the new data directly to the existing CSV file

# Load the existing CSV file
existing_df = pd.read_csv('realistic_clinical_notes.csv')

# Create the new DataFrame (this is the new data to append)
data_new = {
    "PatientID": [f"P05{i+1}" for i in range(10)],
    "Age": [66, 44, 52, 35, 63, 28, 70, 57, 49, 38],
    "Gender": ["Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female"],
    "Ethnicity": ["Caucasian", "African American", "Hispanic", "Asian", "Caucasian", "Hispanic", "African American", "Asian", "Caucasian", "African American"],
    "Doctor": [f"Dr. {random.choice(['Garcia', 'Wang', 'Peterson', 'Lee', 'Young'])}" for _ in range(10)],
    "Medication": random.choices(
        ["Clonazepam", "Lisinopril", "Ceftriaxone", "Metformin", "Atenolol", "Ventolin", "Gabapentin", "Sertraline", "Losartan", "Amoxicillin"],
        k=10),
    "TreatmentPlan": random.choices(
        ["Anxiety management", "Blood pressure control", "Infection treatment", "Diabetes management", "Heart rate control", 
         "Asthma management", "Nerve pain control", "Depression management", "Hypertension control", "Antibiotic course"],
        k=10),
    "DoctorSpecialty": random.choices(
        ["Psychiatrist", "Cardiologist", "Infectious Disease Specialist", "Endocrinologist", "Cardiologist", "Pulmonologist", "Neurologist", "Psychiatrist", "Nephrologist", "Infectious Disease Specialist"],
        k=10),
    "DiagnosisDate": pd.date_range(start="2024-06-01", periods=10).strftime("%Y-%m-%d").tolist(),
    "Clinical Note": [
        "A 66-year-old male presented with symptoms of generalized anxiety, including frequent panic attacks and insomnia. Clonazepam was prescribed for anxiety management, and the patient was advised to follow up in two weeks to assess treatment effectiveness.",
        "The patient, a 44-year-old female, was diagnosed with hypertension during her routine check-up. Lisinopril was added to her treatment plan, and she was counseled on the importance of regular physical activity and a low-sodium diet.",
        "A 52-year-old male presented with fever, chills, and a productive cough. He was diagnosed with bacterial pneumonia and started on Ceftriaxone. The patient was advised to complete the full course of antibiotics and return if symptoms persisted.",
        "The patient, a 35-year-old female with a history of type 2 diabetes, reported difficulty managing her blood sugar levels. Her Metformin dosage was adjusted, and she was provided with dietary counseling to better manage her condition.",
        "A 63-year-old male presented with complaints of palpitations and dizziness. An ECG showed abnormal rhythms, and Atenolol was prescribed to control his heart rate. The patient was advised to monitor his symptoms and follow up with his cardiologist.",
        "A 28-year-old female with a history of asthma reported increased shortness of breath and wheezing. She was prescribed a Ventolin inhaler for symptom management and was instructed on proper inhaler technique.",
        "The patient, a 70-year-old male, reported worsening neuropathic pain in his legs. Gabapentin was prescribed to manage the nerve pain, and the patient was referred to a pain management specialist for further evaluation.",
        "A 57-year-old female with a history of major depressive disorder reported increased feelings of sadness and hopelessness. Her Sertraline dosage was adjusted, and she was encouraged to continue with her therapy sessions.",
        "The patient, a 49-year-old male, presented with uncontrolled hypertension despite adherence to his current medication regimen. Losartan was added to his treatment plan, and lifestyle modifications were recommended.",
        "A 38-year-old female presented with a sore throat, fever, and swollen lymph nodes. She was diagnosed with streptococcal pharyngitis and prescribed Amoxicillin. The patient was advised to complete the antibiotic course and return if symptoms did not improve."
    ],
    "ICD10Code": ["F41.1", "I10", "J18.9", "E11.9", "I47.1", "J45.909", "G62.9", "F33.1", "I12.9", "J02.0"],
    "PrimaryDiagnosis": [
        "Generalized Anxiety Disorder", "Hypertension", "Bacterial Pneumonia", "Type 2 Diabetes Mellitus", "Cardiac Arrhythmia",
        "Asthma", "Peripheral Neuropathy", "Major Depressive Disorder", "Hypertension with Chronic Kidney Disease", "Streptococcal Pharyngitis"],
    "Allergies": ["None", "None", "None", "Sulfa Drugs", "None", "None", "None", "None", "Penicillin", "None"],
    "BloodType": random.choices(["O+", "A+", "B+", "AB+", "O-", "A-", "B-", "AB-"], k=10),
    "SmokingStatus": random.choices(["Former Smoker", "Never Smoked", "Current Smoker"], k=10),
    "AlcoholUse": random.choices(["Occasional", "Never", "Regular"], k=10),
    "BMI": [round(random.uniform(20.0, 34.0), 1) for _ in range(10)],
    "ChronicConditions": [
        "Anxiety", "Hypertension", "Infections", "Diabetes", "Heart Disease", "Asthma", "Neuropathy", "Depression", "Kidney Disease", "Infections"],
    "FamilyHistory": [
        "Mental Health Disorders", "Hypertension", "Infections", "Diabetes", "Heart Disease", "Asthma", "Diabetes", "Mental Health Disorders", "Kidney Disease", "Infections"],
    "MedicationsHistory": ["Clonazepam", "Lisinopril", "Ceftriaxone", "Metformin", "Atenolol", "Ventolin", "Gabapentin", "Sertraline", "Losartan", "Amoxicillin"],
    "Hospitalizations": random.choices([0, 1, 2], k=10),
    "Surgeries": random.choices(
        ["Appendectomy", "None", "None", "None", "None", "None", "None", "None", "None", "Tonsillectomy"], k=10),
    "Immunizations": ["Flu Shot"] * 10,
    "LabResults": [
        "Normal", "Elevated Blood Pressure", "Positive Sputum Culture", "Elevated HbA1c", "Abnormal ECG", "Normal Spirometry", "Elevated Glucose", "Low Serotonin", "Elevated Creatinine", "Positive Strep Test"],
    "PrimaryCareProvider": [f"Dr. {random.choice(['Anderson', 'Martinez', 'Lee', 'Thompson', 'Garcia'])}" for _ in range(10)]
}

# Create the new DataFrame
df_new = pd.DataFrame(data_new)

# Append the new data to the existing DataFrame
combined_df = pd.concat([existing_df, df_new], ignore_index=True)

# Save the combined DataFrame back to the original CSV file
combined_file_path = 'realistic_clinical_notes.csv'
combined_df.to_csv(combined_file_path, index=False)

combined_file_path
# Out:
# 'realistic_clinical_notes.csv'

# %%
# Append the new data directly to the existing CSV file

# Load the existing CSV file
existing_df = pd.read_csv('realistic_clinical_notes.csv')

# Create the new DataFrame (this is the new data to append)
data_new = {
    "PatientID": [f"P06{i+1}" for i in range(10)],
    "Age": [48, 62, 54, 30, 67, 41, 55, 39, 63, 45],
    "Gender": ["Female", "Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female", "Male"],
    "Ethnicity": ["Hispanic", "Caucasian", "African American", "Asian", "Hispanic", "Caucasian", "African American", "Asian", "Caucasian", "Hispanic"],
    "Doctor": [f"Dr. {random.choice(['Lewis', 'Nguyen', 'Brooks', 'Rodriguez', 'Patel'])}" for _ in range(10)],
    "Medication": random.choices(
        ["Warfarin", "Alprazolam", "Enalapril", "Prednisone", "Levothyroxine", "Metformin", "Propranolol", "Omeprazole", "Atorvastatin", "Ventolin"],
        k=10),
    "TreatmentPlan": random.choices(
        ["Blood thinner management", "Anxiety management", "Blood pressure control", "Steroid therapy", "Thyroid hormone replacement", 
         "Diabetes management", "Heart rate control", "Acid reflux management", "Cholesterol management", "Asthma management"],
        k=10),
    "DoctorSpecialty": random.choices(
        ["Cardiologist", "Psychiatrist", "Endocrinologist", "Rheumatologist", "Endocrinologist", "Cardiologist", "Psychiatrist", "Gastroenterologist", "Cardiologist", "Pulmonologist"],
        k=10),
    "DiagnosisDate": pd.date_range(start="2024-07-01", periods=10).strftime("%Y-%m-%d").tolist(),
    "Clinical Note": [
        "A 48-year-old female patient was evaluated for atrial fibrillation. Warfarin was prescribed as a blood thinner, and the patient was instructed to monitor her INR levels regularly. Dietary advice was given to avoid vitamin K-rich foods.",
        "The patient, a 62-year-old male, reported increased anxiety and panic attacks, particularly in social settings. Alprazolam was prescribed for acute anxiety management, and cognitive-behavioral therapy was recommended.",
        "A 54-year-old female presented with uncontrolled hypertension despite her current regimen. Enalapril was added to her treatment plan to better manage her blood pressure, and lifestyle modifications were discussed.",
        "The patient, a 30-year-old male, was diagnosed with severe asthma exacerbation. Prednisone was prescribed as part of his treatment, along with his regular inhaler. He was advised to avoid known triggers and to follow up in two weeks.",
        "A 67-year-old female with a history of hypothyroidism reported fatigue and weight gain. Her Levothyroxine dosage was adjusted based on recent lab results, and she was advised to return for a follow-up in six weeks.",
        "The patient, a 41-year-old male with type 2 diabetes, presented with elevated blood glucose levels. His Metformin dosage was increased, and he was provided with additional dietary counseling to improve glycemic control.",
        "A 55-year-old female presented with complaints of palpitations and anxiety. Propranolol was prescribed for heart rate and anxiety management, and she was advised to monitor her symptoms and reduce caffeine intake.",
        "The patient, a 39-year-old male, reported persistent acid reflux symptoms despite dietary changes. Omeprazole was prescribed, and he was instructed to take the medication 30 minutes before meals for optimal effect.",
        "A 63-year-old female with hyperlipidemia was prescribed Atorvastatin. She was advised to follow a low-fat diet and to have her cholesterol levels checked in three months to assess the effectiveness of the treatment.",
        "A 45-year-old male with a history of asthma reported increased difficulty breathing during physical activity. His Ventolin inhaler dosage was adjusted, and he was advised to use a spacer device for better medication delivery."
    ],
    "ICD10Code": ["I48.91", "F41.0", "I10", "J45.909", "E03.9", "E11.9", "I47.1", "K21.9", "E78.0", "J45.909"],
    "PrimaryDiagnosis": [
        "Atrial Fibrillation", "Generalized Anxiety Disorder", "Hypertension", "Asthma Exacerbation", "Hypothyroidism",
        "Type 2 Diabetes Mellitus", "Tachycardia", "Gastroesophageal Reflux Disease", "Hyperlipidemia", "Asthma"],
    "Allergies": ["None", "None", "Penicillin", "None", "None", "None", "None", "None", "Shellfish", "None"],
    "BloodType": random.choices(["A+", "O+", "B+", "AB+", "O-", "A-", "B-", "AB-"], k=10),
    "SmokingStatus": random.choices(["Former Smoker", "Never Smoked", "Current Smoker"], k=10),
    "AlcoholUse": random.choices(["Occasional", "Never", "Regular"], k=10),
    "BMI": [round(random.uniform(21.0, 35.0), 1) for _ in range(10)],
    "ChronicConditions": [
        "Heart Disease", "Anxiety", "Hypertension", "Asthma", "Hypothyroidism", "Diabetes", "Heart Disease", "GERD", "High Cholesterol", "Asthma"],
    "FamilyHistory": [
        "Heart Disease", "Mental Health Disorders", "Hypertension", "Respiratory Issues", "Thyroid Disorders", "Diabetes", "Heart Disease", "GERD", "Heart Disease", "Respiratory Issues"],
    "MedicationsHistory": ["Warfarin", "Alprazolam", "Enalapril", "Prednisone", "Levothyroxine", "Metformin", "Propranolol", "Omeprazole", "Atorvastatin", "Ventolin"],
    "Hospitalizations": random.choices([0, 1, 2], k=10),
    "Surgeries": random.choices(
        ["None", "None", "None", "Appendectomy", "Thyroidectomy", "None", "None", "None", "None", "None"], k=10),
    "Immunizations": ["Flu Shot"] * 10,
    "LabResults": [
        "Elevated INR", "Elevated Cortisol", "High Blood Pressure", "Normal Spirometry", "Low TSH", "Elevated HbA1c", "Abnormal ECG", "Elevated Acid Levels", "High LDL", "Normal Spirometry"],
    "PrimaryCareProvider": [f"Dr. {random.choice(['Clark', 'Ramirez', 'Harris', 'Martinez', 'Jones'])}" for _ in range(10)]
}

# Create the new DataFrame
df_new = pd.DataFrame(data_new)

# Append the new data to the existing DataFrame
combined_df = pd.concat([existing_df, df_new], ignore_index=True)

# Save the combined DataFrame back to the original CSV file
combined_file_path = 'realistic_clinical_notes.csv'
combined_df.to_csv(combined_file_path, index=False)

combined_file_path
# Out:
# 'realistic_clinical_notes.csv'

# %%
# Append the new data directly to the existing CSV file

# Load the existing CSV file
existing_df = pd.read_csv('realistic_clinical_notes.csv')

# Create the new DataFrame (this is the new data to append)
data_new = {
    "PatientID": [f"P07{i+1}" for i in range(10)],
    "Age": [59, 47, 33, 72, 50, 64, 41, 58, 36, 45],
    "Gender": ["Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female"],
    "Ethnicity": ["Caucasian", "African American", "Hispanic", "Asian", "Caucasian", "Hispanic", "African American", "Asian", "Caucasian", "Hispanic"],
    "Doctor": [f"Dr. {random.choice(['Stewart', 'Diaz', 'Nguyen', 'Thomas', 'Jackson'])}" for _ in range(10)],
    "Medication": random.choices(
        ["Losartan", "Levothyroxine", "Albuterol", "Sertraline", "Warfarin", "Lisinopril", "Ciprofloxacin", "Aspirin", "Metformin", "Gabapentin"],
        k=10),
    "TreatmentPlan": random.choices(
        ["Hypertension control", "Thyroid hormone replacement", "Asthma management", "Depression management", "Blood thinner therapy", 
         "Blood pressure management", "Antibiotic treatment", "Cardiac prevention", "Diabetes management", "Nerve pain control"],
        k=10),
    "DoctorSpecialty": random.choices(
        ["Cardiologist", "Endocrinologist", "Pulmonologist", "Psychiatrist", "Hematologist", "Nephrologist", "Infectious Disease Specialist", "Cardiologist", "Endocrinologist", "Neurologist"],
        k=10),
    "DiagnosisDate": pd.date_range(start="2024-08-01", periods=10).strftime("%Y-%m-%d").tolist(),
    "Clinical Note": [
        "A 59-year-old male with a history of hypertension presented with elevated blood pressure readings despite adherence to his current medication. Losartan was prescribed, and the patient was advised to monitor his blood pressure daily.",
        "The patient, a 47-year-old female, was evaluated for symptoms of fatigue, weight gain, and cold intolerance. She was diagnosed with hypothyroidism, and Levothyroxine was prescribed to normalize her thyroid function.",
        "A 33-year-old male with asthma reported increased wheezing and shortness of breath. Albuterol was prescribed as a rescue inhaler, and he was advised to avoid allergens and continue using his maintenance inhaler.",
        "The patient, a 72-year-old female, has been struggling with depression for several months. Sertraline was prescribed to manage her symptoms, and she was referred to a therapist for cognitive-behavioral therapy.",
        "A 50-year-old male with a history of atrial fibrillation was prescribed Warfarin for stroke prevention. The patient was counseled on the importance of regular INR monitoring and was advised to avoid foods high in vitamin K.",
        "The patient, a 64-year-old female, presented with poorly controlled hypertension. Lisinopril was added to her regimen, and she was advised to reduce sodium intake and engage in regular physical activity.",
        "A 41-year-old male reported symptoms of a urinary tract infection, including dysuria and increased frequency. Ciprofloxacin was prescribed, and he was instructed to complete the full course of antibiotics.",
        "The patient, a 58-year-old female, was seen for primary prevention of cardiovascular disease. Aspirin was prescribed, and she was advised to follow a heart-healthy diet and increase her physical activity.",
        "A 36-year-old male with type 2 diabetes reported high blood glucose levels. His Metformin dosage was increased, and he was educated on the importance of carbohydrate counting and regular blood glucose monitoring.",
        "The patient, a 45-year-old female, presented with neuropathic pain in her extremities. Gabapentin was prescribed for pain management, and she was referred to a neurologist for further evaluation."
    ],
    "ICD10Code": ["I10", "E03.9", "J45.909", "F33.1", "I48.91", "I10", "N39.0", "I25.2", "E11.9", "G62.9"],
    "PrimaryDiagnosis": [
        "Hypertension", "Hypothyroidism", "Asthma", "Major Depressive Disorder", "Atrial Fibrillation",
        "Hypertension", "Urinary Tract Infection", "Cardiovascular Disease Prevention", "Type 2 Diabetes Mellitus", "Peripheral Neuropathy"],
    "Allergies": ["None", "Penicillin", "None", "None", "Shellfish", "None", "None", "None", "None", "None"],
    "BloodType": random.choices(["A+", "O+", "B+", "AB+", "O-", "A-", "B-", "AB-"], k=10),
    "SmokingStatus": random.choices(["Former Smoker", "Never Smoked", "Current Smoker"], k=10),
    "AlcoholUse": random.choices(["Occasional", "Never", "Regular"], k=10),
    "BMI": [round(random.uniform(19.0, 34.0), 1) for _ in range(10)],
    "ChronicConditions": [
        "Hypertension", "Hypothyroidism", "Asthma", "Depression", "Heart Disease", "Hypertension", "Infections", "Heart Disease", "Diabetes", "Neuropathy"],
    "FamilyHistory": [
        "Heart Disease", "Thyroid Disorders", "Respiratory Issues", "Mental Health Disorders", "Heart Disease", "Hypertension", "Infections", "Heart Disease", "Diabetes", "Diabetes"],
    "MedicationsHistory": ["Losartan", "Levothyroxine", "Albuterol", "Sertraline", "Warfarin", "Lisinopril", "Ciprofloxacin", "Aspirin", "Metformin", "Gabapentin"],
    "Hospitalizations": random.choices([0, 1, 2], k=10),
    "Surgeries": random.choices(
        ["None", "Thyroidectomy", "None", "Appendectomy", "None", "None", "None", "None", "None", "Appendectomy"], k=10),
    "Immunizations": ["Flu Shot"] * 10,
    "LabResults": [
        "Elevated Blood Pressure", "Low TSH", "Normal Spirometry", "Low Serotonin", "Elevated INR", "High Blood Pressure", "Positive Urine Culture", "Normal ECG", "Elevated HbA1c", "Abnormal Nerve Conduction"],
    "PrimaryCareProvider": [f"Dr. {random.choice(['Morris', 'Sanchez', 'Reed', 'Carter', 'Mitchell'])}" for _ in range(10)]
}


# Create the new DataFrame
df_new = pd.DataFrame(data_new)

# Append the new data to the existing DataFrame
combined_df = pd.concat([existing_df, df_new], ignore_index=True)

# Save the combined DataFrame back to the original CSV file
combined_file_path = 'realistic_clinical_notes.csv'
combined_df.to_csv(combined_file_path, index=False)

combined_file_path
# Out:
# 'realistic_clinical_notes.csv'

# %%
# Append the new data directly to the existing CSV file

# Load the existing CSV file
existing_df = pd.read_csv('realistic_clinical_notes.csv')

# Create the new DataFrame (this is the new data to append)
data_new = {
    "PatientID": [f"P08{i+1}" for i in range(10)],
    "Age": [51, 60, 42, 69, 38, 56, 47, 53, 61, 44],
    "Gender": ["Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female"],
    "Ethnicity": ["Caucasian", "Asian", "African American", "Hispanic", "Caucasian", "African American", "Hispanic", "Asian", "Caucasian", "African American"],
    "Doctor": [f"Dr. {random.choice(['Smith', 'Johnson', 'Williams', 'Brown', 'Jones'])}" for _ in range(10)],
    "Medication": random.choices(
        ["Metformin", "Amlodipine", "Omeprazole", "Gabapentin", "Atorvastatin", "Levothyroxine", "Lisinopril", "Sertraline", "Albuterol", "Warfarin"],
        k=10),
    "TreatmentPlan": random.choices(
        ["Diabetes management", "Blood pressure control", "GERD management", "Nerve pain control", "Cholesterol management", 
         "Thyroid hormone replacement", "Hypertension control", "Depression management", "Asthma management", "Blood thinner management"],
        k=10),
    "DoctorSpecialty": random.choices(
        ["Endocrinologist", "Cardiologist", "Gastroenterologist", "Neurologist", "Cardiologist", "Endocrinologist", "Nephrologist", "Psychiatrist", "Pulmonologist", "Hematologist"],
        k=10),
    "DiagnosisDate": pd.date_range(start="2024-09-01", periods=10).strftime("%Y-%m-%d").tolist(),
    "Clinical Note": [
        "A 51-year-old male with type 2 diabetes presented with elevated blood glucose levels. His Metformin dosage was adjusted, and he was counseled on dietary changes to improve glycemic control.",
        "The patient, a 60-year-old female, was diagnosed with hypertension. Amlodipine was added to her treatment regimen, and she was advised to monitor her blood pressure at home regularly.",
        "A 42-year-old male reported symptoms of acid reflux, including heartburn and regurgitation. Omeprazole was prescribed, and the patient was advised to avoid trigger foods and elevate the head of his bed.",
        "The patient, a 69-year-old female, has been experiencing neuropathic pain in her feet. Gabapentin was prescribed to manage the pain, and she was referred to a pain management specialist for further evaluation.",
        "A 38-year-old male with a history of hypercholesterolemia was prescribed Atorvastatin. He was counseled on the importance of a low-fat diet and regular exercise to manage his cholesterol levels.",
        "The patient, a 56-year-old female, reported symptoms of hypothyroidism, including fatigue and weight gain. Levothyroxine was prescribed, and she was instructed to have her thyroid function rechecked in six weeks.",
        "A 47-year-old male presented with poorly controlled hypertension. Lisinopril was added to his treatment plan, and he was advised to reduce his sodium intake and increase physical activity.",
        "The patient, a 53-year-old female, has been struggling with depression for several months. Sertraline was prescribed to help manage her symptoms, and she was encouraged to attend regular therapy sessions.",
        "A 61-year-old male with a history of asthma reported increased shortness of breath and wheezing. Albuterol was prescribed as a rescue inhaler, and the patient was advised to avoid known triggers.",
        "The patient, a 44-year-old female with atrial fibrillation, was prescribed Warfarin for stroke prevention. She was counseled on the importance of regular INR monitoring and advised to avoid foods high in vitamin K."
    ],
    "ICD10Code": ["E11.9", "I10", "K21.9", "G62.9", "E78.0", "E03.9", "I10", "F33.1", "J45.909", "I48.91"],
    "PrimaryDiagnosis": [
        "Type 2 Diabetes Mellitus", "Hypertension", "Gastroesophageal Reflux Disease", "Peripheral Neuropathy", "Hypercholesterolemia",
        "Hypothyroidism", "Hypertension", "Major Depressive Disorder", "Asthma", "Atrial Fibrillation"],
    "Allergies": ["None", "None", "Penicillin", "None", "None", "None", "None", "None", "None", "None"],
    "BloodType": random.choices(["A+", "O+", "B+", "AB+", "O-", "A-", "B-", "AB-"], k=10),
    "SmokingStatus": random.choices(["Former Smoker", "Never Smoked", "Current Smoker"], k=10),
    "AlcoholUse": random.choices(["Occasional", "Never", "Regular"], k=10),
    "BMI": [round(random.uniform(19.0, 34.0), 1) for _ in range(10)],
    "ChronicConditions": [
        "Diabetes", "Hypertension", "GERD", "Neuropathy", "High Cholesterol", "Hypothyroidism", "Hypertension", "Depression", "Asthma", "Heart Disease"],
    "FamilyHistory": [
        "Diabetes", "Heart Disease", "GERD", "Neuropathy", "High Cholesterol", "Thyroid Disorders", "Hypertension", "Mental Health Disorders", "Asthma", "Heart Disease"],
    "MedicationsHistory": ["Metformin", "Amlodipine", "Omeprazole", "Gabapentin", "Atorvastatin", "Levothyroxine", "Lisinopril", "Sertraline", "Albuterol", "Warfarin"],
    "Hospitalizations": random.choices([0, 1, 2], k=10),
    "Surgeries": random.choices(
        ["None", "None", "Appendectomy", "None", "None", "Thyroidectomy", "None", "None", "None", "None"], k=10),
    "Immunizations": ["Flu Shot"] * 10,
    "LabResults": [
        "Elevated HbA1c", "High Blood Pressure", "Elevated Acid Levels", "Abnormal Nerve Conduction", "High LDL", "Low TSH", "High Blood Pressure", "Low Serotonin", "Normal Spirometry", "Elevated INR"],
    "PrimaryCareProvider": [f"Dr. {random.choice(['Martin', 'Robinson', 'Clark', 'Walker', 'Rodriguez'])}" for _ in range(10)]
}


# Create the new DataFrame
df_new = pd.DataFrame(data_new)

# Append the new data to the existing DataFrame
combined_df = pd.concat([existing_df, df_new], ignore_index=True)

# Save the combined DataFrame back to the original CSV file
combined_file_path = 'realistic_clinical_notes.csv'
combined_df.to_csv(combined_file_path, index=False)

combined_file_path
# Out:
# 'realistic_clinical_notes.csv'

# %%
# Append the new data directly to the existing CSV file

# Load the existing CSV file
existing_df = pd.read_csv('realistic_clinical_notes.csv')

# Create the new DataFrame (this is the new data to append)
data_new = {
    "PatientID": [f"P09{i+1}" for i in range(10)],
    "Age": [50, 34, 68, 43, 59, 47, 55, 37, 62, 49],
    "Gender": ["Female", "Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female", "Male"],
    "Ethnicity": ["Hispanic", "Caucasian", "African American", "Asian", "Caucasian", "Hispanic", "African American", "Asian", "Caucasian", "Hispanic"],
    "Doctor": [f"Dr. {random.choice(['Anderson', 'Lee', 'Martinez', 'Clark', 'Garcia'])}" for _ in range(10)],
    "Medication": random.choices(
        ["Metoprolol", "Citalopram", "Omeprazole", "Amlodipine", "Prednisone", "Warfarin", "Levothyroxine", "Gabapentin", "Lisinopril", "Atorvastatin"],
        k=10),
    "TreatmentPlan": random.choices(
        ["Blood pressure management", "Depression management", "GERD treatment", "Hypertension control", "Inflammation control", 
         "Blood thinner management", "Thyroid hormone replacement", "Nerve pain management", "Hypertension control", "Cholesterol management"],
        k=10),
    "DoctorSpecialty": random.choices(
        ["Cardiologist", "Psychiatrist", "Gastroenterologist", "Nephrologist", "Rheumatologist", "Hematologist", "Endocrinologist", "Neurologist", "Cardiologist", "Cardiologist"],
        k=10),
    "DiagnosisDate": pd.date_range(start="2024-10-01", periods=10).strftime("%Y-%m-%d").tolist(),
    "Clinical Note": [
        "The patient, a 50-year-old female, has been diagnosed with hypertension. Metoprolol was prescribed to help control her blood pressure, and she was advised to monitor her levels regularly and make necessary lifestyle changes.",
        "A 34-year-old male presented with symptoms of depression, including low energy and loss of interest in activities. Citalopram was prescribed to manage his symptoms, and he was encouraged to participate in regular therapy sessions.",
        "A 68-year-old female reported frequent episodes of heartburn and acid reflux. Omeprazole was prescribed to manage her symptoms, and she was advised to avoid trigger foods and maintain an upright posture after meals.",
        "The patient, a 43-year-old male, was diagnosed with hypertension. Amlodipine was added to his treatment regimen to better control his blood pressure. Dietary modifications and regular physical activity were also recommended.",
        "A 59-year-old female presented with symptoms of severe joint inflammation. Prednisone was prescribed to reduce the inflammation, and she was referred to a rheumatologist for further evaluation.",
        "The patient, a 47-year-old male with a history of atrial fibrillation, was prescribed Warfarin to prevent blood clots. He was instructed to have regular INR checks and avoid foods high in vitamin K.",
        "A 55-year-old female with a history of hypothyroidism reported fatigue and weight gain. Levothyroxine was prescribed, and her thyroid function will be reassessed in six weeks.",
        "The patient, a 37-year-old male, has been experiencing neuropathic pain in his hands. Gabapentin was prescribed to manage the pain, and he was advised to follow up with a neurologist for further testing.",
        "A 62-year-old female with poorly controlled hypertension was prescribed Lisinopril. She was advised to monitor her blood pressure at home and to reduce sodium intake in her diet.",
        "The patient, a 49-year-old male with elevated cholesterol levels, was prescribed Atorvastatin. He was instructed to follow a low-fat diet and engage in regular exercise to improve his lipid profile."
    ],
    "ICD10Code": ["I10", "F33.1", "K21.9", "I10", "M06.9", "I48.91", "E03.9", "G62.9", "I10", "E78.0"],
    "PrimaryDiagnosis": [
        "Hypertension", "Major Depressive Disorder", "Gastroesophageal Reflux Disease", "Hypertension", "Inflammatory Arthritis",
        "Atrial Fibrillation", "Hypothyroidism", "Peripheral Neuropathy", "Hypertension", "Hyperlipidemia"],
    "Allergies": ["None", "None", "Penicillin", "None", "None", "None", "None", "None", "None", "None"],
    "BloodType": random.choices(["A+", "O+", "B+", "AB+", "O-", "A-", "B-", "AB-"], k=10),
    "SmokingStatus": random.choices(["Former Smoker", "Never Smoked", "Current Smoker"], k=10),
    "AlcoholUse": random.choices(["Occasional", "Never", "Regular"], k=10),
    "BMI": [round(random.uniform(20.0, 35.0), 1) for _ in range(10)],
    "ChronicConditions": [
        "Hypertension", "Depression", "GERD", "Hypertension", "Arthritis", "Heart Disease", "Thyroid Disorder", "Neuropathy", "Hypertension", "High Cholesterol"],
    "FamilyHistory": [
        "Heart Disease", "Mental Health Disorders", "GERD", "Hypertension", "Autoimmune Disorders", "Heart Disease", "Thyroid Disorders", "Diabetes", "Hypertension", "Heart Disease"],
    "MedicationsHistory": ["Metoprolol", "Citalopram", "Omeprazole", "Amlodipine", "Prednisone", "Warfarin", "Levothyroxine", "Gabapentin", "Lisinopril", "Atorvastatin"],
    "Hospitalizations": random.choices([0, 1, 2], k=10),
    "Surgeries": random.choices(
        ["None", "None", "Appendectomy", "None", "None", "None", "Thyroidectomy", "None", "None", "None"], k=10),
    "Immunizations": ["Flu Shot"] * 10,
    "LabResults": [
        "High Blood Pressure", "Low Serotonin", "Elevated Acid Levels", "High Blood Pressure", "Elevated ESR", "Elevated INR", "Low TSH", "Abnormal Nerve Conduction", "High Blood Pressure", "Elevated LDL"],
    "PrimaryCareProvider": [f"Dr. {random.choice(['Taylor', 'Miller', 'Wilson', 'Moore', 'Davis'])}" for _ in range(10)]
}


# Create the new DataFrame
df_new = pd.DataFrame(data_new)

# Append the new data to the existing DataFrame
combined_df = pd.concat([existing_df, df_new], ignore_index=True)

# Save the combined DataFrame back to the original CSV file
combined_file_path = 'realistic_clinical_notes.csv'
combined_df.to_csv(combined_file_path, index=False)

combined_file_path
# Out:
# 'realistic_clinical_notes.csv'

# %%
# Append the new data directly to the existing CSV file

# Load the existing CSV file
existing_df = pd.read_csv('realistic_clinical_notes.csv')

# Create the new DataFrame (this is the new data to append)
data_new = {
    "PatientID": [f"P11{i+1}" for i in range(15)],
    "Age": [random.randint(30, 70) for _ in range(15)],
    "Gender": random.choices(["Male", "Female"], k=15),
    "Ethnicity": random.choices(["Caucasian", "Hispanic", "African American", "Asian"], k=15),
    "Doctor": [f"Dr. {random.choice(['Hernandez', 'Brown', 'Nguyen', 'Martinez', 'Lee'])}" for _ in range(15)],
    "Medication": random.choices(
        ["Metformin", "Amlodipine", "Omeprazole", "Gabapentin", "Atorvastatin", "Levothyroxine", "Lisinopril", "Sertraline", "Albuterol", "Warfarin", 
         "Metoprolol", "Citalopram", "Prednisone", "Insulin", "Fluoxetine"],
        k=15),
    "TreatmentPlan": random.choices(
        ["Diabetes management", "Blood pressure control", "GERD management", "Nerve pain control", "Cholesterol management", 
         "Thyroid hormone replacement", "Hypertension control", "Depression management", "Asthma management", "Blood thinner management",
         "Cardiac management", "Mental health support", "Inflammation control", "Insulin therapy", "Mood stabilization"],
        k=15),
    "DoctorSpecialty": random.choices(
        ["Cardiologist", "Psychiatrist", "Gastroenterologist", "Nephrologist", "Rheumatologist", "Hematologist", "Endocrinologist", "Neurologist", "Pulmonologist"],
        k=15),
    "DiagnosisDate": pd.date_range(start="2024-12-01", periods=15).strftime("%Y-%m-%d").tolist(),
    "Clinical Note": [
        "A 55-year-old female presented with symptoms of uncontrolled diabetes. Her Metformin dosage was increased, and she was advised to monitor her blood glucose levels regularly and maintain a balanced diet.",
        "The patient, a 49-year-old male, reported persistent high blood pressure despite current medications. Amlodipine was added to his regimen, and he was encouraged to reduce his salt intake and exercise regularly.",
        "A 62-year-old female complained of chronic acid reflux, especially after meals. Omeprazole was prescribed to alleviate her symptoms, and she was advised to avoid large meals and stay upright for at least 30 minutes after eating.",
        "The patient, a 47-year-old male, has been experiencing neuropathic pain in his lower extremities. Gabapentin was prescribed, and he was referred to a specialist for further pain management options.",
        "A 58-year-old male with hyperlipidemia was prescribed Atorvastatin. He was instructed to follow a low-fat diet and return for a lipid panel test in three months.",
        "The patient, a 60-year-old female with hypothyroidism, reported weight gain and fatigue. Her Levothyroxine dosage was adjusted, and she was scheduled for a follow-up thyroid function test in six weeks.",
        "A 43-year-old male presented with hypertension that has been difficult to control. Lisinopril was added to his treatment plan, and lifestyle changes such as increased physical activity and dietary modifications were recommended.",
        "The patient, a 50-year-old female, reported worsening symptoms of depression. Sertraline was prescribed to manage her symptoms, and she was encouraged to continue therapy sessions regularly.",
        "A 38-year-old male with a history of asthma reported increased shortness of breath. Albuterol was prescribed as a rescue inhaler, and he was advised to avoid allergens and triggers that could worsen his condition.",
        "The patient, a 66-year-old female with atrial fibrillation, was prescribed Warfarin to prevent blood clots. She was instructed on the importance of regular INR monitoring and advised to avoid foods high in vitamin K.",
        "A 45-year-old male with a history of hypertension was started on Metoprolol to manage his blood pressure. He was advised to monitor his blood pressure at home and make necessary lifestyle adjustments.",
        "The patient, a 34-year-old female, presented with symptoms of anxiety and low mood. Citalopram was prescribed to help manage her symptoms, and she was referred to a mental health specialist for further support.",
        "A 57-year-old male with rheumatoid arthritis reported joint pain and swelling. Prednisone was prescribed to reduce inflammation, and he was referred to a rheumatologist for long-term management.",
        "The patient, a 63-year-old female with type 1 diabetes, was prescribed Insulin to control her blood glucose levels. She was educated on proper injection techniques and the importance of regular blood sugar monitoring.",
        "A 39-year-old male reported experiencing mood swings and episodes of depression. Fluoxetine was prescribed to stabilize his mood, and he was encouraged to maintain a regular exercise routine to support his mental health."
    ],
    "ICD10Code": ["E11.9", "I10", "K21.9", "G62.9", "E78.0", "E03.9", "I10", "F33.1", "J45.909", "I48.91", 
                  "I10", "F41.1", "M06.9", "E10", "F32.9"],
    "PrimaryDiagnosis": [
        "Type 2 Diabetes Mellitus", "Hypertension", "Gastroesophageal Reflux Disease", "Peripheral Neuropathy", "Hyperlipidemia",
        "Hypothyroidism", "Hypertension", "Major Depressive Disorder", "Asthma", "Atrial Fibrillation",
        "Hypertension", "Generalized Anxiety Disorder", "Rheumatoid Arthritis", "Type 1 Diabetes Mellitus", "Major Depressive Disorder"],
    "Allergies": random.choices(["None", "Penicillin", "Sulfa Drugs", "None", "None", "None", "None", "None", "None", "None"], k=15),
    "BloodType": random.choices(["A+", "O+", "B+", "AB+", "O-", "A-", "B-", "AB-"], k=15),
    "SmokingStatus": random.choices(["Former Smoker", "Never Smoked", "Current Smoker"], k=15),
    "AlcoholUse": random.choices(["Occasional", "Never", "Regular"], k=15),
    "BMI": [round(random.uniform(19.0, 35.0), 1) for _ in range(15)],
    "ChronicConditions": [
        "Diabetes", "Hypertension", "GERD", "Neuropathy", "High Cholesterol", "Hypothyroidism", "Hypertension", "Depression", "Asthma", "Heart Disease",
        "Hypertension", "Anxiety", "Arthritis", "Diabetes", "Depression"],
    "FamilyHistory": [
        "Diabetes", "Heart Disease", "GERD", "Neuropathy", "High Cholesterol", "Thyroid Disorders", "Hypertension", "Mental Health Disorders", "Asthma", "Heart Disease",
        "Hypertension", "Anxiety", "Autoimmune Disorders", "Diabetes", "Depression"],
    "MedicationsHistory": random.choices(
        ["Metformin", "Amlodipine", "Omeprazole", "Gabapentin", "Atorvastatin", "Levothyroxine", "Lisinopril", "Sertraline", "Albuterol", "Warfarin", 
         "Metoprolol", "Citalopram", "Prednisone", "Insulin", "Fluoxetine"],
        k=15),
    "Hospitalizations": random.choices([0, 1, 2], k=15),
    "Surgeries": random.choices(
        ["None", "None", "Appendectomy", "None", "None", "None", "Thyroidectomy", "None", "None", "None"], k=15),
    "Immunizations": ["Flu Shot"] * 15,
    "LabResults": [
        "Elevated HbA1c", "High Blood Pressure", "Elevated Acid Levels", "Abnormal Nerve Conduction", "High LDL", "Low TSH", "High Blood Pressure", "Low Serotonin", "Normal Spirometry", "Elevated INR",
        "Elevated Blood Pressure", "Low Cortisol", "High ESR", "Elevated Glucose", "Abnormal ECG"],
    "PrimaryCareProvider": [f"Dr. {random.choice(['Taylor', 'Miller', 'Wilson', 'Moore', 'Davis'])}" for _ in range(15)]
}


# Create the new DataFrame
df_new = pd.DataFrame(data_new)

# Append the new data to the existing DataFrame
combined_df = pd.concat([existing_df, df_new], ignore_index=True)

# Save the combined DataFrame back to the original CSV file
combined_file_path = 'realistic_clinical_notes.csv'
combined_df.to_csv(combined_file_path, index=False)

combined_file_path
# Out:
# 'realistic_clinical_notes.csv'

# %%
# Append the new data directly to the existing CSV file

# Load the existing CSV file
existing_df = pd.read_csv('realistic_clinical_notes.csv')

# Create the new DataFrame (this is the new data to append)
data_new = {
    "PatientID": [f"P12{i+1}" for i in range(15)],
    "Age": [random.randint(30, 70) for _ in range(15)],
    "Gender": random.choices(["Male", "Female"], k=15),
    "Ethnicity": random.choices(["Caucasian", "Hispanic", "African American", "Asian"], k=15),
    "Doctor": [f"Dr. {random.choice(['Johnson', 'Smith', 'Williams', 'Brown', 'Jones'])}" for _ in range(15)],
    "Medication": random.choices(
        ["Metformin", "Amlodipine", "Omeprazole", "Gabapentin", "Atorvastatin", "Levothyroxine", "Lisinopril", "Sertraline", "Albuterol", "Warfarin", 
         "Metoprolol", "Citalopram", "Prednisone", "Insulin", "Fluoxetine"],
        k=15),
    "TreatmentPlan": random.choices(
        ["Diabetes management", "Blood pressure control", "GERD management", "Nerve pain control", "Cholesterol management", 
         "Thyroid hormone replacement", "Hypertension control", "Depression management", "Asthma management", "Blood thinner management",
         "Cardiac management", "Mental health support", "Inflammation control", "Insulin therapy", "Mood stabilization"],
        k=15),
    "DoctorSpecialty": random.choices(
        ["Cardiologist", "Psychiatrist", "Gastroenterologist", "Nephrologist", "Rheumatologist", "Hematologist", "Endocrinologist", "Neurologist", "Pulmonologist"],
        k=15),
    "DiagnosisDate": pd.date_range(start="2025-01-01", periods=15).strftime("%Y-%m-%d").tolist(),
    "Clinical Note": [
        "The patient, a 64-year-old male, was seen for management of his type 2 diabetes. His Metformin dosage was increased due to elevated blood glucose levels. Dietary adjustments and regular exercise were strongly recommended.",
        "A 52-year-old female presented with symptoms of high blood pressure. Amlodipine was prescribed to help control her hypertension, and she was advised to monitor her blood pressure at home and follow a low-sodium diet.",
        "The patient, a 46-year-old male, complained of persistent heartburn and acid reflux. Omeprazole was prescribed, and he was advised to avoid spicy foods and maintain an upright posture after eating.",
        "A 60-year-old female with a history of neuropathy reported worsening pain in her feet. Gabapentin was prescribed to help manage her symptoms, and she was referred to a pain specialist for further care.",
        "The patient, a 49-year-old male, was diagnosed with hyperlipidemia. Atorvastatin was prescribed to lower his cholesterol levels, and he was advised to return in three months for a follow-up lipid panel.",
        "A 55-year-old female with hypothyroidism presented with fatigue and weight gain. Her Levothyroxine dosage was adjusted, and she was instructed to have her thyroid function rechecked in six weeks.",
        "A 43-year-old male with hypertension that is not well-controlled was prescribed Lisinopril. He was advised to monitor his blood pressure at home and make dietary and lifestyle changes to better manage his condition.",
        "The patient, a 48-year-old female, has been struggling with symptoms of depression. Sertraline was prescribed to help manage her mood, and she was encouraged to attend regular therapy sessions.",
        "A 35-year-old male with a history of asthma reported increased shortness of breath and wheezing. Albuterol was prescribed as a rescue inhaler, and the patient was advised to avoid known triggers.",
        "The patient, a 67-year-old female with atrial fibrillation, was prescribed Warfarin to prevent blood clots. She was instructed to have regular INR checks and avoid foods high in vitamin K.",
        "A 50-year-old male with a history of hypertension was prescribed Metoprolol to help manage his blood pressure. He was advised to monitor his blood pressure at home and make lifestyle adjustments.",
        "The patient, a 33-year-old female, reported symptoms of anxiety and low mood. Citalopram was prescribed to help manage her symptoms, and she was referred to a mental health specialist for ongoing care.",
        "A 58-year-old male with rheumatoid arthritis reported joint pain and stiffness. Prednisone was prescribed to reduce inflammation, and he was referred to a rheumatologist for further management.",
        "The patient, a 65-year-old female with type 1 diabetes, was prescribed Insulin to manage her blood glucose levels. She was educated on proper injection techniques and the importance of regular blood sugar monitoring.",
        "A 41-year-old male reported experiencing mood swings and episodes of depression. Fluoxetine was prescribed to help stabilize his mood, and he was encouraged to maintain a regular exercise routine."
    ],
    "ICD10Code": ["E11.9", "I10", "K21.9", "G62.9", "E78.0", "E03.9", "I10", "F33.1", "J45.909", "I48.91", 
                  "I10", "F41.1", "M06.9", "E10", "F32.9"],
    "PrimaryDiagnosis": [
        "Type 2 Diabetes Mellitus", "Hypertension", "Gastroesophageal Reflux Disease", "Peripheral Neuropathy", "Hyperlipidemia",
        "Hypothyroidism", "Hypertension", "Major Depressive Disorder", "Asthma", "Atrial Fibrillation",
        "Hypertension", "Generalized Anxiety Disorder", "Rheumatoid Arthritis", "Type 1 Diabetes Mellitus", "Major Depressive Disorder"],
    "Allergies": random.choices(["None", "Penicillin", "Sulfa Drugs", "None", "None", "None", "None", "None", "None", "None"], k=15),
    "BloodType": random.choices(["A+", "O+", "B+", "AB+", "O-", "A-", "B-", "AB-"], k=15),
    "SmokingStatus": random.choices(["Former Smoker", "Never Smoked", "Current Smoker"], k=15),
    "AlcoholUse": random.choices(["Occasional", "Never", "Regular"], k=15),
    "BMI": [round(random.uniform(19.0, 35.0), 1) for _ in range(15)],
    "ChronicConditions": [
        "Diabetes", "Hypertension", "GERD", "Neuropathy", "High Cholesterol", "Hypothyroidism", "Hypertension", "Depression", "Asthma", "Heart Disease",
        "Hypertension", "Anxiety", "Arthritis", "Diabetes", "Depression"],
    "FamilyHistory": [
        "Diabetes", "Heart Disease", "GERD", "Neuropathy", "High Cholesterol", "Thyroid Disorders", "Hypertension", "Mental Health Disorders", "Asthma", "Heart Disease",
        "Hypertension", "Anxiety", "Autoimmune Disorders", "Diabetes", "Depression"],
    "MedicationsHistory": random.choices(
        ["Metformin", "Amlodipine", "Omeprazole", "Gabapentin", "Atorvastatin", "Levothyroxine", "Lisinopril", "Sertraline", "Albuterol", "Warfarin", 
         "Metoprolol", "Citalopram", "Prednisone", "Insulin", "Fluoxetine"],
        k=15),
    "Hospitalizations": random.choices([0, 1, 2], k=15),
    "Surgeries": random.choices(
        ["None", "None", "Appendectomy", "None", "None", "None", "Thyroidectomy", "None", "None", "None"], k=15),
    "Immunizations": ["Flu Shot"] * 15,
    "LabResults": [
        "Elevated HbA1c", "High Blood Pressure", "Elevated Acid Levels", "Abnormal Nerve Conduction", "High LDL", "Low TSH", "High Blood Pressure", "Low Serotonin", "Normal Spirometry", "Elevated INR",
        "Elevated Blood Pressure", "Low Cortisol", "High ESR", "Elevated Glucose", "Abnormal ECG"],
    "PrimaryCareProvider": [f"Dr. {random.choice(['Taylor', 'Miller', 'Wilson', 'Moore', 'Davis'])}" for _ in range(15)]
}


# Create the new DataFrame
df_new = pd.DataFrame(data_new)

# Append the new data to the existing DataFrame
combined_df = pd.concat([existing_df, df_new], ignore_index=True)

# Save the combined DataFrame back to the original CSV file
combined_file_path = 'realistic_clinical_notes.csv'
combined_df.to_csv(combined_file_path, index=False)

combined_file_path
# Out:
# 'realistic_clinical_notes.csv'
